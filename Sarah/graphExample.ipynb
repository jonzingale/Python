# %% [markdown]
# # MatPlotLib Graph
#
# Here I demonstrate displaying a graphs generally,<br>
# and specifically a simple Excel-like graph using<br>
# the MatPlotLib library in python.<br>

# %%
import linegraph as lg

# %%
lg.table()
lg.graphLines()
lg.barGraph()
